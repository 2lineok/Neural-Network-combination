# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
print(yest[-1])
# Out:
# 20526.774668693542
# 0.0763532817363739
# 3.598001512727933e-06
# 1.495594005973544e-06

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], "g--",label="MSE_loss_Sup")
plt.plot(yesntest[:ll], "g",label="Newton_loss_Sup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "r--",label="MSE_loss_Unsup")
plt.plot(yesntest[:ll], "r",label="Newton_loss_Unsup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "b--",label="MSE_loss_Comb")
plt.plot(yesntest[:ll], "b",label="Newton_loss_Comb")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 1946922
# length is 3700003
# 1070504
# length is 2040003
# 928836
# length is 1770003
# 27569.73117518425

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], "g--",label="MSE_loss_Sup")
plt.plot(yesntest[:ll], "g",label="Newton_loss_Sup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "r--",label="MSE_loss_Unsup")
plt.plot(yesntest[:ll], "r",label="Newton_loss_Unsup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "b--",label="MSE_loss_Comb")
plt.plot(yesntest[:ll], "b",label="Newton_loss_Comb")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], "g--",label="MSE_loss_Sup")
plt.plot(yesntest[:ll], "g",label="Newton_loss_Sup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "r--",label="MSE_loss_Unsup")
plt.plot(yesntest[:ll], "r",label="Newton_loss_Unsup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "b--",label="MSE_loss_Comb")
plt.plot(yesntest[:ll], "b",label="Newton_loss_Comb")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 1653608
# length is 3610003
# 772099
# length is 3560003
# 667533
# length is 3350003
# 71230.39106583595

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], "g--",label="MSE_loss_Sup")
plt.plot(yesntest[:ll], "g",label="Newton_loss_Sup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "r--",label="MSE_loss_Unsup")
plt.plot(yesntest[:ll], "r",label="Newton_loss_Unsup")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], "b--",label="MSE_loss_Comb")
plt.plot(yesntest[:ll], "b",label="Newton_loss_Comb")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 2643964
# length is 4350003
# 1810002
# length is 4010003
# 1439039
# length is 3230003
# 39514.35674118996

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 2830153
# length is 3170003
# 2150116
# length is 2760003
# 1527254
# length is 3980003
# 49725.976517915726

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 2860002
# length is 3140003
# 1707122
# length is 4050003
# 1497553
# length is 4770003
# 51392.745742082596

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=-1






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 2860002
# length is 3140003
# 1707122
# length is 4050003
# 1497553
# length is 5540003
# 62642.91723227501

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

tt=3600*5

# Perform the operation
count = (time1_tensor < tt).sum().item()
print(count)
print("length is",len(yest))

plt.plot(time1[:count],yestest[:count], label="'MSE_loss_Sup'")
plt.plot(time1[:count],yesntest[:count], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < tt).sum().item()
print(count)
print("length is",len(yest))

plt.plot(time1[:count],yestest[:count], label="'MSE_loss_Unsup'")
plt.plot(time1[:count],yesntest[:count], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < tt).sum().item()
print(count)
print("length is",len(yest))

plt.plot(time1[:count],yestest[:count], label="'MSE_loss_Comb'")
plt.plot(time1[:count],yesntest[:count], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("Time (sec)")



plt.show()
print(time1[-1])
# Out:
# 3510500
# length is 3580003
# 3067009
# length is 3110003
# 2133939
# length is 2180003
# 18449.08681821823

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 2852232
# length is 3580003
# 2510832
# length is 3110003
# 1747334
# length is 2180003
# 18449.08681821823

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=3800000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 3160002
# length is 7340005
# 2722772
# length is 4510003
# 1930163
# length is 3220003
# 33184.78557229042

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=2000000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 3160002
# length is 7340005
# 2479992
# length is 6010004
# 1772654
# length is 4120003
# 40467.29983282089

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
ll=4000000






print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Sup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Sup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Unsup'")
plt.plot(yesntest[:ll], label="'Newton_loss_Unsup'")

#plt.legend(loc="upper left")
#plt.yscale("log")
#plt.legend()
#plt.legend(loc='upper left')




import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param

time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)

print("length is",len(yest))
plt.plot(yestest[:ll], label="'MSE_loss_Comb'")
plt.plot(yesntest[:ll], label="'Newton_loss_Comb'")

#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.xlabel("# Iterations")



plt.show()
print(time1[-1])
# Out:
# 3160002
# length is 7340005
# 2479992
# length is 6010004
# 1772654
# length is 4120003
# 40467.29983282089

# %%
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
#print(yest[-1])
# Out:
# 20526.774668693542
# 0.0763532817363739
# 3.598001512727933e-06

# %%
time1[2852459]
# Out:
# 14400.00617814064

# %%
plt.plot(yestest[:2852459], label="'MSE_losstest'")
plt.plot(yesntest[:2852459], label="'Newton_losstest'")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.title("Supervised")
plt.show()
print("time is",time1[2852459])
print(yesntest[2852459])
print(yestest[2852459])
# Out:
# time is 14400.00617814064
# 0.08348249644041061
# 4.222759343974758e-06

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10ch12")

yes,yesn,yes1,yesn1,yestest,yesntest,yest,when,lamda,time1=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
print(yest[-1])
# Out:
# 34545.38269972801
# 0.0012828134931623936
# 2.5092226678680163e-06
# 0.0006581117631867528

# %%
import torch

# Convert list to tensor
time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
# Out:
# 1771904

# %%
plt.plot(yestest[:1771904], label="'MSE_losstest'")
plt.plot(yesntest[:1771904], label="'Newton_losstest'")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.title("Lambda is 1/2")
plt.show()
print("time is",time1[1771904])
print(yesntest[1771904])
print(yestest[1771904])
# Out:
# time is 14400.003976345062
# 0.0026225601322948933
# 4.0593081394035835e-06

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.unsup")

yes,yesn,yes1,yesn1,yestest,yesntest,yest,when,lamda,time1=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
print(yest[-1])
# Out:
# 29287.812472343445
# 0.005918796639889479
# 1.7703727280604653e-05
# 0.006718807388097048

# %%
import torch

# Convert list to tensor
time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
# Out:
# 2380002

# %%
plt.plot(yestest[:2380002], label="'MSE_losstest'")
plt.plot(yesntest[:2380002], label="'Newton_losstest'")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.title("Unsupervised")
plt.show()
print("time is",time1[2380002])
print(yesntest[2380002])
print(yestest[2380002])
# Out:
# time is 14413.799864768982
# 0.010437180288136005
# 3.4463238989701495e-05

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.j")

yes,yesn,yes1,yesn1,yestest,yesntest,yest,when,lamda,time1=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
print(yest[-1])
# Out:
# 38087.29835271835
# 0.006134469993412495
# 4.275932496966561e-06
# 7.656100024178158e-06

# %%
import torch

# Convert list to tensor
time1_tensor = torch.tensor(time1)

# Perform the operation
count = (time1_tensor < 14400).sum().item()
print(count)
# Out:
# 2213459

# %%
plt.plot(yestest[:2213459], label="'MSE_losstest'")
plt.plot(yesntest[:2213459], label="'Newton_losstest'")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.title("Jump from supervised")
plt.show()
print("time is",time1[2213459])
print(yesntest[2213459])
print(yestest[2213459])
# Out:
# time is 14400.002024650574
# 0.026552462950348854
# 2.1197107344050892e-05

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10ch1")

yes,yesn,yes1,yesn1,yestest,yesntest,yest,when,lamda=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10chj")

yes,yesn,yes1,yesn1,yestest,yesntest,yest,when,lamda=obj.param


plt.plot(yes, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yes1, label="'MSE_loss1'")
plt.plot(yesn1, label="'Newton_loss1'")
plt.plot(yestest, label="'MSE_losstest'")
plt.plot(yesntest, label="'Newton_losstest'")
plt.plot(yest, label="'Train_loss'")
plt.vlines(x = when, ymin = min(min(yes),min(yesn)) , ymax = max(max(yes),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-only")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-onlyre")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-7")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
print(lamda)
print(yesn[-1])
print(yes1[-1])
print(yest[-1])
# Out:
# 0.01
# 0.0011317426105961204
# 1.2752337852361961e-06
# 1.3244154615676962e-05

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-onlyre")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
print(yesn[-1])
print(yes1[-1])
# Out:
# 0.0007164882263168693
# 1.907532350742258e-06

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-5")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1[0:400001], label="'MSE_loss'")
plt.plot(yesn[0:400001], label="'Newton_loss'")
plt.plot(yest[0:400001], label="'tt'")
#plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-5")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1[0:100001], label="'MSE_loss'")
plt.plot(yesn[0:100001], label="'Newton_loss'")
plt.plot(yest[0:100001], label="'tt'")
#plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-5")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1[0:800001], label="'MSE_loss'")
plt.plot(yesn[0:800001], label="'Newton_loss'")
plt.plot(yest[0:800001], label="'tt'")
#plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
plt.vlines(x = when[0], ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-6")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
print(when)
# Out:
# [480000, 490000, 540000, 920000, 3080000, 9480000]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-7re")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn[:200000], label="'Newton_loss'")
#plt.plot(yest, label="'tt'")
plt.vlines(x = when[0], ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn[:2000], label="'Newton_loss'")
#plt.plot(yest, label="'tt'")
plt.vlines(x = when[0], ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-712")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()
# Out:
# Error during unpickling object (Possibly unsupported): [Errno 2] No such file or directory: 'data.10-712'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 25
#      21         print("Error during unpickling object (Possibly unsupported):", ex)
#      23 obj = load_object("data.10-712")
# ---> 25 yes1,yesn,yest,when,epoch,lamda=obj.param
#      28 plt.plot(yes1, label="'MSE_loss'")
#      29 plt.plot(yesn, label="'Newton_loss'")
#
# AttributeError: 'NoneType' object has no attribute 'param'

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-5re")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-6re")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-5re")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1[:350000], label="'MSE_loss'")
plt.plot(yesn[:350000], label="'Newton_loss'")
#plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
obj = load_object("/home/skl5876/Data_set/NN/data.sup")

yes,yesn,yes1,yesn1,yestest,yesntest,yestest1,yesntest1,yest,when,lamda,time1=obj.param


plt.plot(yest, label="'Train_loss'")
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.legend(loc='upper left')
plt.show()
print(time1[-1])
print(yesntest[-1])
print(yestest[-1])
print(yest[-1])
# Out:
# 3430.3573944568634
# 2.3694891929626465
# 0.0005013218615204096
# 0.0004915302852168679

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load the model


import pickle

class MyClass():
    def __init__(self, param):
        self.param = param
 
def load_object(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error during unpickling object (Possibly unsupported):", ex)
 
obj = load_object("data.10-6l")

yes1,yesn,yest,when,epoch,lamda=obj.param


plt.plot(yes1, label="'MSE_loss'")
plt.plot(yesn, label="'Newton_loss'")
plt.plot(yest, label="'tt'")
plt.vlines(x = when, ymin = min(min(yes1),min(yesn)) , ymax = max(max(yes1),max(yesn)), color = 'b')
#plt.legend(loc="upper left")
plt.yscale("log")
plt.legend()
plt.show()
